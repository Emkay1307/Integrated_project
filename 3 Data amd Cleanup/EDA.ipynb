# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
insurance_data = pd.read_excel('insurance_claims_raw.xlsx')

# %%
insurance_data.head()
# Out:
#    months_as_customer   age  policy_number policy_bind_date policy_state  \
# 0                 328  48.0         521585       2014-10-17           OH
# 1                 228  42.0         342868       2006-06-27           IN
# 2                 134  29.0         687698       2000-09-06           OH
# 3                 256  41.0         227811       1990-05-25           IL
# 4                 228  44.0         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500             1000.0                1406.91               0
# 1    250/500             2000.0                1197.22         5000000
# 2    100/300             2000.0                1413.14         5000000
# 3    250/500             2000.0                1415.74         6000000
# 4   500/1000             1000.0                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          998 non-null    float64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   datetime64[ns]
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            998 non-null    float64
#  7   policy_annual_premium        997 non-null    float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      999 non-null    object
# ...

# %%
insurance_data.isnull().sum()
# Out:
# months_as_customer                0
# age                               2
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 2
# policy_annual_premium             3
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           1
# insured_occupation                0
# insured_hobbies                   2
# insured_relationship              0
# capital-gains                     2
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            93
# incident_state                    2
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
age_mean = insurance_data['age'].mean()
age_median = insurance_data['age'].median()
age_mode = stats.mode(insurance_data['age'])

# Display the mean, median, and mode of the 'age' column
print(f"Mean age: {age_mean}")
print(f"Median age: {age_median}")
print(f"Mode age: {age_mode.mode[0]} (occurs {age_mode.count[0]} times)")
# Out:
# Mean age: 38.96292585170341
# Median age: 38.0
# Mode age: 43.0 (occurs 49 times)
# C:\Users\EpicDeals\AppData\Local\Temp\ipykernel_8056\4265438099.py:3: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   age_mode = stats.mode(insurance_data['age'])

# %%
ge_mean = insurance_data['age'].mean()
age_median = insurance_data['age'].median()
age_mode = stats.mode(insurance_data['age']).mode[0]

# Create a histogram for the 'age' column
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
plt.hist(insurance_data['age'], bins=20, edgecolor='black')  # Create a histogram with 20 bins

# Plot vertical lines for mean, median, and mode
plt.axvline(age_mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {age_mean:.2f}')
plt.axvline(age_median, color='green', linestyle='dashed', linewidth=1, label=f'Median: {age_median}')
plt.axvline(age_mode, color='blue', linestyle='dashed', linewidth=1, label=f'Mode: {age_mode}')

# Set labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age Distribution with Mean, Median, and Mode')

# Show legend
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\EpicDeals\AppData\Local\Temp\ipykernel_8056\320470697.py:3: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   age_mode = stats.mode(insurance_data['age']).mode[0]

# %%
deductible_mean = insurance_data['policy_deductable'].mean()
deductible_median = insurance_data['policy_deductable'].median()
deductible_mode = stats.mode(insurance_data['policy_deductable']).mode[0]

# Create a histogram for the 'policy_deductable' column
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
plt.hist(insurance_data['policy_deductable'], bins=20, edgecolor='black')  # Create a histogram with 20 bins

# Plot vertical lines for mean, median, and mode
plt.axvline(deductible_mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {deductible_mean:.2f}')
plt.axvline(deductible_median, color='green', linestyle='dashed', linewidth=1, label=f'Median: {deductible_median}')
plt.axvline(deductible_mode, color='blue', linestyle='dashed', linewidth=1, label=f'Mode: {deductible_mode}')

# Set labels and title
plt.xlabel('Policy Deductible')
plt.ylabel('Frequency')
plt.title('Histogram of Policy Deductible Distribution with Mean, Median, and Mode')

# Show legend
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\EpicDeals\AppData\Local\Temp\ipykernel_8056\1999256128.py:3: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   deductible_mode = stats.mode(insurance_data['policy_deductable']).mode[0]

# %%
# Calculate the mean, median, and mode of the 'policy_annual_premium' column
premium_mean = insurance_data['policy_annual_premium'].mean()
premium_median = insurance_data['policy_annual_premium'].median()
premium_mode = stats.mode(insurance_data['policy_annual_premium']).mode[0]

# Create a histogram for the 'policy_annual_premium' column
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
plt.hist(insurance_data['policy_annual_premium'], bins=20, edgecolor='black')  # Create a histogram with 20 bins

# Plot vertical lines for mean, median, and mode
plt.axvline(premium_mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {premium_mean:.2f}')
plt.axvline(premium_median, color='green', linestyle='dashed', linewidth=1, label=f'Median: {premium_median}')
plt.axvline(premium_mode, color='blue', linestyle='dashed', linewidth=1, label=f'Mode: {premium_mode}')

# Set labels and title
plt.xlabel('Policy Annual Premium')
plt.ylabel('Frequency')
plt.title('Histogram of Policy Annual Premium Distribution with Mean, Median, and Mode')

# Show legend
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\EpicDeals\AppData\Local\Temp\ipykernel_8056\4120766503.py:4: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   premium_mode = stats.mode(insurance_data['policy_annual_premium']).mode[0]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a count plot for 'insured_education_level'
plt.figure(figsize=(8, 6))
sns.countplot(data=insurance_data, x='insured_education_level', edgecolor='black')

# Set labels and title
plt.xlabel('Insured Education Level')
plt.ylabel('Frequency')
plt.title('Count of Insured Education Levels')

# Rotate x-labels for better readability (if needed)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
from statistics import mode

# Calculate the mode of 'insured_education_level'
education_level_mode = mode(insurance_data['insured_education_level'])

print(f"The mode of 'insured_education_level' is: {education_level_mode}")
# Out:
# The mode of 'insured_education_level' is: JD

# %%
# Create a count plot for 'insured_hobbies'
plt.figure(figsize=(10, 6))
sns.countplot(data=insurance_data, x='insured_hobbies', edgecolor='black')

# Set labels and title
plt.xlabel('Insured Hobbies')
plt.ylabel('Frequency')
plt.title('Count of Insured Hobbies')

# Rotate x-labels for better readability (if needed)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Calculate the mode of 'insured_hobbies'
hobbies_mode = mode(insurance_data['insured_hobbies'])
print(f"The mode of 'insured_hobbies' is: {hobbies_mode}")
# Out:
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# The mode of 'insured_hobbies' is: reading

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# Calculate the mean, median, and mode of 'capital-gains'
capital_gains_mean = insurance_data['capital-gains'].mean()
capital_gains_median = insurance_data['capital-gains'].median()
capital_gains_mode = stats.mode(insurance_data['capital-gains']).mode[0]

# Create a histogram for 'capital-gains' column
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
plt.hist(insurance_data['capital-gains'], bins=20, edgecolor='black')  # Create a histogram with 20 bins

# Plot vertical lines for mean, median, and mode
plt.axvline(capital_gains_mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {capital_gains_mean:.2f}')
plt.axvline(capital_gains_median, color='green', linestyle='dashed', linewidth=1, label=f'Median: {capital_gains_median}')
plt.axvline(capital_gains_mode, color='blue', linestyle='dashed', linewidth=1, label=f'Mode: {capital_gains_mode}')

# Set labels and title
plt.xlabel('Capital Gains')
plt.ylabel('Frequency')
plt.title('Histogram of Capital Gains Distribution with Mean, Median, and Mode')

# Show legend
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\EpicDeals\AppData\Local\Temp\ipykernel_8056\3789260227.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   capital_gains_mode = stats.mode(insurance_data['capital-gains']).mode[0]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statistics import mode

# Create a count plot for 'authorities_contacted'
plt.figure(figsize=(8, 6))
sns.countplot(data=insurance_data, x='authorities_contacted', edgecolor='black')

# Calculate the mode of 'authorities_contacted'
authorities_mode = mode(insurance_data['authorities_contacted'])

# Set labels and title
plt.xlabel('Authorities Contacted')
plt.ylabel('Frequency')
plt.title('Count of Authorities Contacted')

# Rotate x-labels for better readability (if needed)
plt.xticks(rotation=45)

# Show the mode as an annotation on the plot
plt.text(0.5, 0.8, f'Mode: {authorities_mode}', fontsize=12, ha='center', va='center', transform=plt.gca().transAxes)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statistics import mode

# Create a count plot for 'incident_state'
plt.figure(figsize=(10, 6))
sns.countplot(data=insurance_data, x='incident_state', edgecolor='black')

# Calculate the mode of 'incident_state'
incident_state_mode = mode(insurance_data['incident_state'])

# Set labels and title
plt.xlabel('Incident State')
plt.ylabel('Frequency')
plt.title('Count of Incident States')

# Rotate x-labels for better readability (if needed)
plt.xticks(rotation=45)

# Show the mode as an annotation on the plot
plt.text(0.5, 0.8, f'Mode: {incident_state_mode}', fontsize=12, ha='center', va='center', transform=plt.gca().transAxes)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Calculate the mean, median, and mode of 'total_claim_amount'
total_claim_mean = insurance_data['total_claim_amount'].mean()
total_claim_median = insurance_data['total_claim_amount'].median()
total_claim_mode = mode(insurance_data['total_claim_amount'])

# Create a histogram for 'total_claim_amount' column
plt.figure(figsize=(8, 6))
sns.histplot(insurance_data['total_claim_amount'], bins=20, kde=True, color='skyblue')

# Plot vertical lines for mean, median, and mode
plt.axvline(total_claim_mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {total_claim_mean:.2f}')
plt.axvline(total_claim_median, color='green', linestyle='dashed', linewidth=1, label=f'Median: {total_claim_median}')
plt.axvline(total_claim_mode, color='blue', linestyle='dashed', linewidth=1, label=f'Mode: {total_claim_mode}')

# Set labels and title
plt.xlabel('Total Claim Amount')
plt.ylabel('Frequency')
plt.title('Histogram of Total Claim Amount with Mean, Median, and Mode')

# Show legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Calculate the mean, median, and mode of 'injury_claim'
injury_claim_mean = insurance_data['injury_claim'].mean()
injury_claim_median = insurance_data['injury_claim'].median()
injury_claim_mode = mode(insurance_data['injury_claim'])

# Create a histogram for 'injury_claim' column
plt.figure(figsize=(8, 6))
sns.histplot(insurance_data['injury_claim'], bins=20, kde=True, color='skyblue')

# Plot vertical lines for mean, median, and mode
plt.axvline(injury_claim_mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {injury_claim_mean:.2f}')
plt.axvline(injury_claim_median, color='green', linestyle='dashed', linewidth=1, label=f'Median: {injury_claim_median}')
plt.axvline(injury_claim_mode, color='blue', linestyle='dashed', linewidth=1, label=f'Mode: {injury_claim_mode}')

# Set labels and title
plt.xlabel('Injury Claim')
plt.ylabel('Frequency')
plt.title('Histogram of Injury Claim with Mean, Median, and Mode')

# Show legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Calculate the mean, median, and mode of 'property_claim'
property_claim_mean = insurance_data['property_claim'].mean()
property_claim_median = insurance_data['property_claim'].median()
property_claim_mode = mode(insurance_data['property_claim'])

# Create a histogram for 'property_claim' column
plt.figure(figsize=(8, 6))
sns.histplot(insurance_data['property_claim'], bins=20, kde=True, color='skyblue')

# Plot vertical lines for mean, median, and mode
plt.axvline(property_claim_mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {property_claim_mean:.2f}')
plt.axvline(property_claim_median, color='green', linestyle='dashed', linewidth=1, label=f'Median: {property_claim_median}')
plt.axvline(property_claim_mode, color='blue', linestyle='dashed', linewidth=1, label=f'Mode: {property_claim_mode}')

# Set labels and title
plt.xlabel('Property Claim')
plt.ylabel('Frequency')
plt.title('Histogram of Property Claim with Mean, Median, and Mode')

# Show legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\EpicDeals\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
insurance_data['_c39'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: _c39, dtype: float64

# %%
# Assuming your DataFrame is named 'insurance_data'
insurance_data.drop('_c39', axis=1, inplace=True)

# %%
insurance_data.head()
# Out:
#    months_as_customer   age  policy_number policy_bind_date policy_state  \
# 0                 328  48.0         521585       2014-10-17           OH
# 1                 228  42.0         342868       2006-06-27           IN
# 2                 134  29.0         687698       2000-09-06           OH
# 3                 256  41.0         227811       1990-05-25           IL
# 4                 228  44.0         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500             1000.0                1406.91               0
# 1    250/500             2000.0                1197.22         5000000
# 2    100/300             2000.0                1413.14         5000000
# 3    250/500             2000.0                1415.74         6000000
# 4   500/1000             1000.0                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# ...

# %%
# Assuming your DataFrame is named 'insurance_data'
insurance_data['age'].fillna(38, inplace=True)

# %%
# Assuming your DataFrame is named 'insurance_data'
insurance_data['policy_deductable'].fillna(1000, inplace=True)

# %%
# Assuming your DataFrame is named 'insurance_data'
insurance_data['policy_annual_premium'].fillna(1257.83, inplace=True)

# %%
# Assuming your DataFrame is named 'insurance_data'
insurance_data['insured_education_level'].fillna('JD', inplace=True)

# %%
# Assuming your DataFrame is named 'insurance_data'
insurance_data['insured_hobbies'].fillna('reading', inplace=True)

# %%
# Assuming your DataFrame is named 'insurance_data'
insurance_data['capital-gains'].fillna(25176.45, inplace=True)

# %%
# Assuming your DataFrame is named 'insurance_data'
insurance_data['authorities_contacted'].fillna('police', inplace=True)

# %%
# Assuming your DataFrame is named 'insurance_data'
insurance_data['incident_state'].fillna('NY', inplace=True)

# %%
# Assuming your DataFrame is named 'insurance_data'
insurance_data['total_claim_amount'].fillna(57935, inplace=True)

# %%
# Assuming your DataFrame is named 'insurance_data'
insurance_data['injury_claim'].fillna(6780, inplace=True)

# %%
# Assuming your DataFrame is named 'insurance_data' and the blank values are empty strings ''
insurance_data['property_claim'].fillna(6750, inplace=True)

# %%
insurance_data.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...
